# %% [markdown]
# <h1 style="color:orange">EXERCISE CLASS 1 (Part 3/3)</h1>
#
# Final remarks and conclusions

# %% [markdown]
# The normal (gaussian) distribution
#
# ![Slide39.PNG](attachment:Slide39.PNG)

# %% [markdown]
# How to generate random numbers from a given distribution?

# %%
# Import the necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#generate 1000 random data from normal (0,1)
mu=0
sigma=1
n=1000

data = np.random.normal(mu,sigma,n)

#plot the data
plt.hist(data, bins=20)
# Out:
# (array([  5.,  10.,  18.,  45.,  59.,  90., 120., 134., 139., 148.,  91.,
#          58.,  47.,  26.,   5.,   3.,   1.,   0.,   0.,   1.]),
#  array([-2.9366621 , -2.57060426, -2.20454641, -1.83848857, -1.47243073,
#         -1.10637288, -0.74031504, -0.3742572 , -0.00819936,  0.35785849,
#          0.72391633,  1.08997417,  1.45603202,  1.82208986,  2.1881477 ,
#          2.55420555,  2.92026339,  3.28632123,  3.65237907,  4.01843692,
#          4.38449476]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# Normality and independence
#
# ![Slide42.PNG](attachment:Slide42.PNG)

# %% [markdown]
# The Central Limit Theorem (1/2)
#
# ![Slide43.PNG](attachment:Slide43.PNG)
#
# The Central Limit Theorem (2/2)
#
# ![Slide44.PNG](attachment:Slide44.PNG)
#
# In the end...
#
# ![Slide45.PNG](attachment:Slide45.PNG)
